# %%
x=10
y=3

# %%
name="jasleen"
city="lucknow"

# %%
x=10

# %%
x=3.145

# %%
x=True

# %%
x=None

# %%
x=(1,2,3)

# %%
x="hello"

# %%
x=[1,2,3,4]

# %%
x={1,2,3,3,2,1}

# %%
x={'a':'Apple','b':'berry'}

# %%
city
# Out:
# 'lucknow'

# %%
x
# Out:
# {'a': 'Apple', 'b': 'berry'}

# %%
print("hello there")
# Out:
# hello there

# %%
print("hi",'how r u?')
# Out:
# hi how r u?

# %%
x=10
y='apples'
print(x,y)
print(f'i have{x} {y}')
# Out:
# 10 apples
# i have10 apples

# %%
qty=10
price=50
print(f'total amount={qty*price}')
# Out:
# total amount=500

# %%
item=input('enter item name:')
print(item)
# Out:
# laptop

# %%
x=int(input("enter a number:"))
print(x)
# Out:
# 10

# %%
a=int(input("A"))
b=int(input("B"))
c=a+b
print(f'{c=}')
# Out:
# c=35
